# %% [markdown]
# <a href="https://www.kaggle.com/code/ahmedfakhar123/ml-38-logistic-regression-with-perceptron?scriptVersionId=344152571" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ---
# # 🧠 ML 38 — Logistic Regression with Perceptron
#
# ---

# %% [markdown]
# # What is Logistic Regression?

# %% [markdown]
# # Making Data
