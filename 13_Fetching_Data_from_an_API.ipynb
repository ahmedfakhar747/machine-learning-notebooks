# %% [markdown]
# <a href="https://www.kaggle.com/code/ahmedfakhar123/ml-lab-04-fetching-data-from-an-api?scriptVersionId=339264980" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ---
#
# # 💻 ML Lab 04 — Fetching Data from an API

# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1")

# %%
columns = [
    "id",
    "title",
    "original_title",
    "original_language",
    "genre_ids",
    "overview",
    "release_date",
    "popularity",
    "vote_average",
    "vote_count"
]

# %%
df = pd.DataFrame(response.json()["results"])[columns]
df.head()
# Out:
#         id                            title                   original_title  \
# 0   980431  Avatar Aang: The Last Airbender  Avatar Aang: The Last Airbender
# 1  1632181              Accidental Partners             Socias por accidente
# 2  1007757                          Swapped                          Swapped
# 3      278         The Shawshank Redemption         The Shawshank Redemption
# 4   936075                          Michael                          Michael
#
#   original_language            genre_ids  \
# 0                en     [16, 28, 12, 14]
# 1                es          [35, 10749]
# 2                en  [12, 16, 10751, 14]
# 3                en             [18, 80]
# 4                en          [10402, 18]
#
#                                             overview release_date  popularity  \
# 0  Avatar Aang, the world's last Airbender, learn...   2026-07-24    303.9461
# 1  Two women discover they were both scammed by t...   2026-03-12     28.9079
# ...

# %%
df1 = pd.DataFrame()

# %%
for i in range(1, 500):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}')
    temp_df = pd.DataFrame(response.json()['results'])[columns]
    df1 = pd.concat([df1, temp_df] ,ignore_index=True)

# %%
df1
# Out:
#            id                            title  \
# 0      980431  Avatar Aang: The Last Airbender
# 1     1632181              Accidental Partners
# 2     1007757                          Swapped
# 3         278         The Shawshank Redemption
# 4      936075                          Michael
# ...       ...                              ...
# 9975    50135                   Animals United
# 9976  1249289                           Alarum
# 9977     9586      The Bonfire of the Vanities
# 9978    14365                Killing Me Softly
# 9979    10727                   Darkness Falls
#
#                        original_title original_language            genre_ids  \
# 0     Avatar Aang: The Last Airbender                en     [16, 28, 12, 14]
# 1                Socias por accidente                es          [35, 10749]
# 2                             Swapped                en  [12, 16, 10751, 14]
# 3            The Shawshank Redemption                en             [18, 80]
# ...

# %%
df1.to_csv("movies_metadata.csv")
