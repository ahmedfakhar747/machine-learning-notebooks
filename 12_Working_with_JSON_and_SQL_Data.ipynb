# %% [markdown]
# ---
# # 💻 ML Lab 03 — Working with JSON & SQL Data
#
# ### ***Learn how to import and work with JSON files and SQL databases using Pandas***
#
# ---

# %% [markdown]
# Datasets are often stored in **JSON files**, retrieved from **REST APIs**, or managed inside **SQL databases**. As a Machine Learning Engineer or Data Scientist, you'll frequently need to import data from these sources before you can clean, analyze, or train models.
#
# In this lab, you'll learn how to use **Pandas** to work with **JSON files**, fetch data from **APIs**, and read data directly from **SQL databases**. These are essential skills for handling real-world data and building practical Machine Learning applications.
#
# By the end of this notebook, you'll be able to confidently load and work with data from multiple sources, taking another important step toward becoming a Machine Learning Engineer. 🚀

# %% [markdown]
# # 1. Importing Library
# First we have to import necessary library `Pandas`.

# %%
import pandas as pd

# %% [markdown]
# # 2. Working with JSON

# %%
pd.read_json('/kaggle/input/datasets/sterby/german-recipes-dataset/recipes.json')
# Out:
#                                                      Url  \
# 0       https://www.chefkoch.de/rezepte/185441079701305/
# 1      https://www.chefkoch.de/rezepte/2718181424631245/
# 2        https://www.chefkoch.de/rezepte/46341015661368/
# 3        https://www.chefkoch.de/rezepte/51051018014178/
# 4      https://www.chefkoch.de/rezepte/1555771262860408/
# ...                                                  ...
# 12185  https://www.chefkoch.de/rezepte/1547251261244879/
# 12186    https://www.chefkoch.de/rezepte/47411016028870/
# 12187  https://www.chefkoch.de/rezepte/1102041216136522/
# 12188      https://www.chefkoch.de/rezepte/897988359371/
# 12189    https://www.chefkoch.de/rezepte/34751011686647/
#
#                                             Instructions  \
# 0      Die Eier hart kochen. Dann pellen und mit eine...
# 1      Vorab folgende Bemerkung: Alle Mengen sind Cir...
# 2      Die Kirschen abtropfen lassen, dabei den Saft ...
# ...

# %% [markdown]
# # 3. Working with SQL

# %%
# Import libraries
import sqlite3
import pandas as pd

# Step 1: Connect to the SQLite database
conn = sqlite3.connect(
    "/kaggle/input/datasets/rtatman/188-million-us-wildfires/FPA_FOD_20170508.sqlite"
)

# Step 2: Write an SQL query
query = """
SELECT *
FROM spatial_ref_sys
LIMIT 5;
"""

# Step 3: Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, conn)

# Step 4: Close the database connection
conn.close()

# Step 5: Display the DataFrame
df.head()
# Out:
#    srid auth_name  auth_srid                              ref_sys_name  \
# 0    -1      NONE         -1                     Undefined - Cartesian
# 1     0      NONE          0           Undefined - Geographic Long/Lat
# 2  2000      epsg       2000  Anguilla 1957 / British West Indies Grid
# 3  2001      epsg       2001   Antigua 1943 / British West Indies Grid
# 4  2002      epsg       2002  Dominica 1945 / British West Indies Grid
#
#                                            proj4text  \
# 0
# 1
# 2  +proj=tmerc +lat_0=0 +lon_0=-62 +k=0.999500000...
# 3  +proj=tmerc +lat_0=0 +lon_0=-62 +k=0.999500000...
# 4  +proj=tmerc +lat_0=0 +lon_0=-62 +k=0.999500000...
#
#                                               srtext
# 0                                          Undefined
# 1                                          Undefined
# 2  PROJCS["Anguilla 1957 / British West Indies Gr...
# 3  PROJCS["Antigua 1943 / British West Indies Gri...
# ...

# %% [markdown]
# ---
# # 📚 Conclusion
#
# Congratulations! 🎉
#
# In this lab, you learned how to import data from sources beyond traditional CSV files using **Pandas**.
#
# You explored how to:
#
# - 📄 Read JSON files
# - 🌐 Load JSON data directly from APIs
# - 🗄️ Connect to SQL databases
# - 🔍 Execute SQL queries using Pandas
# - 📊 Convert query results into DataFrames for analysis
#
# These skills are essential for working with real-world datasets, as Machine Learning data often comes from **web APIs**, **JSON files**, and **databases** rather than a single CSV file.
#
# You now have a solid foundation for importing data from multiple sources and preparing it for data analysis and Machine Learning projects. 🚀

# %% [markdown]
# ---
#
# # 🚀 What's Next?
#
# [**💻 ML Lab 04 — Fetching Data from an API**](http://https://www.kaggle.com/code/ahmedfakhar123/ml-lab-04-fetching-data-from-an-api)
#
# In the next lab, you'll learn how to retrieve real-time data directly from web APIs using Python.
#
# You'll learn:
#
# - 🌐 What APIs are and how they work
# - 📨 Understanding HTTP requests and responses
# - 🚀 Sending GET requests using the `requests` library
# - 🔑 Working with API endpoints and parameters
# - 📦 Parsing JSON responses
# - 📊 Converting API data into Pandas DataFrames
# - ⚠️ Handling common API errors and exceptions
#
# By the end of this lab, you'll be able to collect live data from public APIs and use it in your Data Science and Machine Learning projects.
#
# ---
#
# # ❤️ Support
#
# If you found this notebook helpful:
#
# - ⭐ Upvote this notebook
# - 💬 Share your feedback in the comments
# - 🔁 Share it with fellow learners
# - 🚀 Follow me for more beginner-friendly AI, Data Science, and Machine Learning content
#
# Happy Learning! 🤖
