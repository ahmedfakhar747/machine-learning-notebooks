# %% [markdown]
# <a href="https://www.kaggle.com/code/ahmedfakhar123/ml-01-what-is-machine-learning?scriptVersionId=337364315" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ---
# # 🤖 What is Machine Learning?
#
# ### *Understanding the Foundation of Artificial Intelligence*
#
# ---

# %% [markdown]
# ## 📖 Overview
#
# > ***Machine Learning (ML)*** is a branch of ***Artificial Intelligence (AI)*** that enables computers to ***learn patterns*** from data and make predictions or decisions without being explicitly programmed for every task. Instead of following fixed rules, machine learning models improve their performance by ***learning from examples***.
#
# In this notebook, you'll explore the fundamental concept of machine learning, understand how it differs from traditional programming, learn why it is important, and discover real-world applications that power many of today's intelligent systems.
#
# <div align="center">
#     <img src="https://www.inesa-tech.com/wp-content/uploads/2026/05/machine-learning-3-e1743106627426.webp" width=500>
#     <img src="https://img.computing.es/wp-content/uploads/2023/12/04092939/machine-learning.jpg" width=500>
# </div>
#
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# * Understand what Machine Learning is.
# * Differentiate Machine Learning from traditional programming.
# * Recognize how machines learn from data.
# * Explore common real-world applications of Machine Learning.
# * Build a strong foundation for advanced ML concepts.
#
#
# ## 🛠️ Prerequisites
#
# Before starting this notebook, you should have:
#
# * Basic Python knowledge
# * Familiarity with datasets and variables
# * Curiosity about Artificial Intelligence 😊

# %% [markdown]
# ---
#
# # ❓ Why Do We Need Machine Learning?
#
# Traditional programming works well when rules are clear and easy to define.
#
# However, many real-world problems are too complex to solve using manually written rules.
#
# Examples include:
#
# - 📧 Spam Email Detection
# - 😊 Face Recognition
# - 🎤 Speech Recognition
# - 🚗 Self-Driving Cars
# - 🎬 Movie Recommendations
# - 💳 Fraud Detection
#
# For these problems, Machine Learning automatically discovers patterns from data instead of relying on manually written instructions.

# %% [markdown]
# ---
#
# # ⚖️ Traditional Programming vs Machine Learning
#
# | Traditional Programming | Machine Learning |
# |-------------------------|------------------|
# | Rules are written manually. | Rules are learned from data. |
# | Input + Program → Output | Input + Output → Model |
# | Best for rule-based problems. | Best for prediction and pattern recognition. |
# | Requires code changes to improve. | Improves with more or better data. |
#
# <div align="center">
#     <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ1MbnGwigmixHgaUMLtCeiwUBTLthxfRD_6jPjqzRsTw&s=10" width=800>
# </div>

# %% [markdown]
# ---
#
# # 📊 Types of Learning Problems
#
# Although there are multiple types of Machine Learning, they generally fall into:
#
# - 📘 Supervised Learning
# - 📙 Unsupervised Learning
# - 📗 Reinforcement Learning
#
# > These will be covered in upcoming notebooks.

# %% [markdown]
# ---
#
# # 🔄 Basic Machine Learning Workflow
#
# A typical Machine Learning project follows these steps:
#
# <div align="center">
#     <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT-Q8kifg4BCASeWARBev6s_i5E9YaQyzCB89XV9MBe0R694fMNCtiKsgI&s=10" width=600>
# </div>
#
# ```text
# Collect Data
#       │
#       ▼
# Prepare & Clean Data
#       │
#       ▼
# Choose an ML Algorithm
#       │
#       ▼
# Train the Model
#       │
#       ▼
# Evaluate Performance
#       │
#       ▼
# Make Predictions
# ```

# %% [markdown]
# ---
#
# # 🌍 Real-World Applications
#
# Machine Learning powers many applications we use every day.
#
# | Domain | Application |
# |---------|-------------|
# | 📧 Email | Spam Detection |
# | 🎬 Entertainment | Movie Recommendations |
# | 🛍️ E-commerce | Product Recommendations |
# | 🏦 Finance | Fraud Detection |
# | 🏥 Healthcare | Disease Prediction |
# | 🚗 Transportation | Self-Driving Cars |
# | 💬 AI | Chatbots & Virtual Assistants |
# | 📱 Social Media | Content Recommendations |

# %% [markdown]
# ---
#
# # ⭐ Advantages of Machine Learning
#
# - Learns automatically from data.
# - Handles complex problems efficiently.
# - Improves as more data becomes available.
# - Reduces the need for manually written rules.
# - Can uncover hidden patterns in large datasets.
#
# ---
#
# # ⚠️ Limitations
#
# - Requires quality data.
# - Can be computationally expensive.
# - Models may be difficult to interpret.
# - Poor data often leads to poor predictions.

# %% [markdown]
# ---
#
# # 🎯 Key Takeaways
#
# - Machine Learning is a subset of Artificial Intelligence.
# - Instead of writing rules, we allow computers to learn from data.
# - Machine Learning is ideal for solving complex problems where explicit programming is difficult.
# - Data is the most important component of every Machine Learning system.
#
# ---
#
# # 📌 Summary
#
# In this notebook, we introduced the fundamental concept of Machine Learning, explored why it is needed, compared it with traditional programming, examined its workflow, and looked at real-world applications. This knowledge forms the foundation for understanding more advanced Machine Learning algorithms and techniques.

# %% [markdown]
# ---
#
# ## 📚 What's Next?
#
# ➡️ [**🤖 ML 02 — AI vs Machine Learning vs Deep Learning**](https://www.kaggle.com/code/ahmedfakhar123/ml-02-ai-vs-machine-learning-vs-deep-learning/edit)
# - Supervised Learning
# - Unsupervised Learning
# - Reinforcement Learning
#
# ---
#
# # ⭐ Support
#
# If you found this notebook helpful, please consider:
#
# - ⭐ Upvoting this notebook
# - 💬 Sharing your feedback in the comments
# - 🔄 Following my profile for future Machine Learning notebooks
# - 🍴 Forking or saving the notebook for future reference
#
# Your support motivates me to create more high-quality content for the AI & Machine Learning community.
#
# **Happy Learning! 🚀**
