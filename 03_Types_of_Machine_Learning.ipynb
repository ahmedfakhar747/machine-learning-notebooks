# %% [markdown]
# <a href="https://www.kaggle.com/code/ahmedfakhar123/ml-03-types-of-machine-learning?scriptVersionId=337408345" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>
