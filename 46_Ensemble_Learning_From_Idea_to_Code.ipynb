# %% [markdown]
# <a href="https://www.kaggle.com/code/ahmedfakhar123/ml-46-ensemble-learning-from-idea-to-code?scriptVersionId=349798266" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ---
#
# # 🤖 ML 46 — Ensemble Learning | From Idea to Code
