# %% [markdown]
# <a href="https://www.kaggle.com/code/ahmedfakhar123/ml-46-ensemble-learning-from-idea-to-code?scriptVersionId=349796872" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ---
#
# # 🤖 ML 46 — Ensemble Learning | From Idea to Code

# %% [markdown]
# ## 🤔 A Question to Think About
#
# Imagine you've trained a Machine Learning model, but it doesn't make correct predictions every time.
#
# **Should you keep searching for one “perfect” model, or could combining the predictions of multiple models give you a better result? 🤔**
#
# That's exactly the idea behind **Ensemble Learning**.

# %% [markdown]
# # Introduction

# %% [markdown]
# # Wisdom of the Crowd

# %% [markdown]
# # Types of Ensemble Learning
#
# 1. Voting
# 2. Bagging
# 3. Stacking
# 4. Boosting

# %% [markdown]
# # Why Ensemble Learning

# %% [markdown]
# # Graphical Explaination

# %% [markdown]
# # Advantages & Disadvantages

# %% [markdown]
# # When to use it?
