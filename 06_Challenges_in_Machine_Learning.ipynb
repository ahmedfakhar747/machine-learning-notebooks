# %% [markdown]
# <a href="https://www.kaggle.com/code/ahmedfakhar123/ml-06-challenges-in-machine-learning?scriptVersionId=338047188" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ---
# # 🤖 ML 06 — Challenges in Machine Learning
#
# ### *Understanding the Common Problems That Affect Machine Learning Models*
#
# ---

# %% [markdown]
# > Building a Machine Learning model is only half the journey.
# >
# > In the real world, ML engineers spend a significant amount of time **collecting data, cleaning it, improving model performance, and deploying models successfully.**
# >
# > Even the most advanced algorithms can fail if the underlying data or learning process has problems.
# >
# > Understanding these challenges is essential for becoming a successful AI Engineer.
#
# <div align="center">
#     <img src="https://nixustechnologies.com/wp-content/uploads/2023/03/ml-challenges.webp" width=450>
#     <img src="https://www.slideteam.net/media/catalog/product/cache/1280x720/c/h/challenges_and_limitations_of_machine_learning_ppt_powerpoint_presentation_slides_slide01.jpg" width=550>
# </div>

# %% [markdown]
# ---
#
# # 🎯 Learning Objectives
#
# By the end of this notebook, you will understand:
#
# - ✅ Why Machine Learning projects fail
# - ✅ The most common challenges in ML
# - ✅ How each challenge affects model performance
# - ✅ Practical examples of each challenge
# - ✅ Basic ways to overcome these problems
#
# ---
#
# # 🏗️ Why Do Machine Learning Models Fail?
#
# Many beginners think that choosing the best algorithm guarantees success.
#
# In reality,
#
# > **The quality of the data and the way the model is built matter much more than the algorithm itself.**
#
# A poor dataset can make even the world's best algorithm perform badly.

# %% [markdown]
# ---
#
# # 1️⃣ Data Collection
#
# ## 📖 What is Data Collection?
#
# Data Collection is the process of gathering information that will be used to train a Machine Learning model.
#
# Since Machine Learning learns from examples,
#
# **better data leads to better models.**
#
#
# <div align="center">
#     <img src="https://www.questionpro.com/blog/wp-content/uploads/2018/08/data-collection.jpg" width=500>
# </div>
#
# ## 🌍 Example
#
# Imagine building a model that predicts house prices.
#
# You collect:
#
# - House size
# - Number of bedrooms
# - Location
# - Age of house
# - Selling price
#
# These become your training data.
#
#
# ## ⚠️ Challenges
#
# - Difficult to obtain enough data
# - Expensive
# - Time-consuming
# - Privacy concerns
# - Data may come from multiple sources
#
#
# ## ✅ Best Practices
#
# - Collect data from reliable sources
# - Gather diverse examples
# - Keep data updated
# - Remove duplicate records

# %% [markdown]
# ---
#
# # 2️⃣ Insufficient Training Data
#
# ## 📖 What is Insufficient Data?
#
# Machine Learning models need lots of examples.
#
# If the dataset is too small,
#
# the model cannot learn meaningful patterns.
#
# <div align="center">
#     <img src="https://quotefancy.com/media/wallpaper/3840x2160/1849837-Arthur-Conan-Doyle-Quote-How-dangerous-it-is-to-reason-from.jpg" width=500>
# </div>
#
# ## 🌍 Example
#
# Teaching a student only **5 math questions** before an exam.
#
# They won't perform well because they haven't seen enough examples.
#
# The same happens with ML models.
#
#
# ## ⚠️ Problems
#
# - Poor accuracy
# - Weak generalization
# - High variance
# - Unstable predictions
#
#
# ## ✅ Possible Solutions
#
# - Collect more data
# - Data augmentation
# - Synthetic data generation
# - Transfer learning

# %% [markdown]
# ---
#
# # 3️⃣ Non-Representative Data
#
# ## 📖 What is Non-Representative Data?
#
# Training data should represent the real-world population.
#
# If important groups are missing,
#
# the model becomes biased.
#
#
# ## 🌍 Example
#
# Suppose a face recognition model is trained mostly on adults.
#
# It may perform poorly when recognizing children.
#
#
# ## ⚠️ Problems
#
# - Biased predictions
# - Poor generalization
# - Unfair results
#
#
# ## ✅ Possible Solutions
#
# - Collect balanced datasets
# - Include all categories
# - Regularly update training data

# %% [markdown]
# ---
#
# # 4️⃣ Poor Quality Data
#
# ## 📖 What is Poor Quality Data?
#
# Poor-quality data contains:
#
# - Missing values
# - Incorrect values
# - Duplicate records
# - Noise
# - Outliers
#
# <div align="center">
#     <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTrzoX-1lAOaHUY6QeT8uBWQ1gddBqk2lp1_pcxVuMSkA&s=10" width=500>
# </div>
#
# ## 🌍 Example
#
# Age column:
#
# ```
# 23
# 25
# 999
# ?
# -5
# ```
#
# Clearly, some values are invalid.
#
#
# ## ⚠️ Problems
#
# - Wrong predictions
# - Lower accuracy
# - Unstable models
#
#
# ## ✅ Possible Solutions
#
# - Data cleaning
# - Handle missing values
# - Remove duplicates
# - Detect outliers
# - Normalize data

# %% [markdown]
# ---
#
# # 5️⃣ Irrelevant Features
#
# ## 📖 What are Irrelevant Features?
#
# Not every column in a dataset helps the model.
#
# Some features provide no useful information.
#
#
# ## 🌍 Example
#
# Predicting house prices:
#
# Useful:
#
# - Area
# - Bedrooms
# - Location
#
# Irrelevant:
#
# - Owner's favorite color
# - House ID
#
# These add noise instead of useful information.
#
#
# ## ⚠️ Problems
#
# - Lower accuracy
# - Longer training time
# - Increased complexity
#
#
# ## ✅ Possible Solutions
#
# - Feature Selection
# - Feature Engineering
# - Correlation Analysis
# - Domain knowledge

# %% [markdown]
# ---
#
# # 6️⃣ Overfitting
#
# ## 📖 What is Overfitting?
#
# Overfitting happens when the model memorizes the training data instead of learning general patterns.
#
# It performs:
#
# - Excellent on training data ✅
# - Poor on unseen data ❌
#
# <div align="center">
#     <img src="https://www.investopedia.com/thmb/DczvN0PFp_86srRgjN5avl0xoa0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/Overfitting-final-476607938cd5400389f77e9e1fb51e47.png" width=500>
# </div>
#
# ## 🌍 Real-Life Analogy
#
# A student memorizes past exam answers without understanding the concepts.
#
# When the exam changes,
#
# they fail.
#
#
# ## ⚠️ Causes
#
# - Very complex models
# - Small datasets
# - Too many features
#
#
# ## ✅ Solutions
#
# - More training data
# - Cross-validation
# - Regularization
# - Simpler models
# - Early stopping

# %% [markdown]
# ---
#
# # 7️⃣ Underfitting
#
# ## 📖 What is Underfitting?
#
# Underfitting occurs when the model is too simple to learn the underlying pattern.
#
# It performs poorly on both training and testing data.
#
# <div align="center">
#     <img src="https://miro.medium.com/0*9dMWQGuWz5SiiBw7" width=500>
# </div>
#
# ## 🌍 Real-Life Analogy
#
# A student studies only one page for an entire subject.
#
# They fail every exam because they didn't learn enough.
#
#
# ## ⚠️ Causes
#
# - Oversimplified model
# - Too little training
# - Poor feature selection
#
#
# ## ✅ Solutions
#
# - Increase model complexity
# - Add better features
# - Train longer
# - Use a better algorithm

# %% [markdown]
# ---
#
# # 8️⃣ Software Integration
#
# ## 📖 What is Software Integration?
#
# A Machine Learning model is only useful if it can work with real software.
#
# It needs to integrate with:
#
# - Websites
# - Mobile apps
# - Cloud services
# - APIs
# - Databases
#
# <div align="center">
#     <img src="https://invozone-backend.s3.amazonaws.com/software_development_and_integration_services_455df1cd4b.webp" width=500>
# </div>
#
# ## 🌍 Example
#
# A fraud detection model must connect with an online banking system to analyze transactions in real time.
#
#
# ## ⚠️ Challenges
#
# - Deployment complexity
# - Compatibility issues
# - Scalability
# - Latency
# - Security
#
#
# ## ✅ Best Practices
#
# - Use APIs
# - Containerize with Docker
# - Monitor production systems
# - Test before deployment

# %% [markdown]
# ---
#
# # 9️⃣ Offline Learning & Deployment
#
# ## 📖 What is Offline Learning?
#
# Offline (Batch) Learning means the model is trained once using existing data.
#
# To learn new information,
#
# it must be retrained.
#
# Deployment is the process of making the trained model available for real-world use.
#
# <div align="center">
#     <img src="https://ch.mathworks.com/content/dam/mathworks/videos/w/what-is-mlops.mp4/jcr:content/renditions/cq5dam.user-uploaded-1.thumbnail.1280.720.jpg" width=500>
# </div>
#
# ## 🌍 Challenges
#
# - Retraining takes time
# - New data isn't learned immediately
# - Deployment can introduce bugs
# - Model performance may degrade over time (concept drift)
#
#
# ## ✅ Best Practices
#
# - Retrain models regularly
# - Monitor performance
# - Automate deployment pipelines
# - Use version control for models

# %% [markdown]
# ---
#
# # 🔟 Cost Involved
#
# ## 📖 Why is Machine Learning Expensive?
#
# Building an ML system involves many costs beyond writing code.
#
#
# ### Common Costs
#
# - Data collection
# - Data labeling
# - Cloud computing
# - GPUs
# - Storage
# - Model deployment
# - Maintenance
# - Skilled engineers
#
#
# ## 🌍 Example
#
# Training a large deep learning model may require multiple high-end GPUs running continuously, increasing infrastructure costs.
#
#
# ## ✅ Cost Reduction Strategies
#
# - Start with simple models
# - Use cloud resources efficiently
# - Reuse pre-trained models
# - Optimize training pipelines
# - Remove unnecessary features

# %% [markdown]
# ---
#
# # 📊 Summary Table
#
# | Challenge | Main Problem | Possible Solution |
# |------------|--------------|-------------------|
# | 📥 Data Collection | Hard to gather quality data | Reliable and diverse data sources |
# | 📉 Insufficient Data | Model can't learn enough | Collect more data or use augmentation |
# | ⚖️ Non-Representative Data | Biased predictions | Balanced datasets |
# | 🗑️ Poor Quality Data | Incorrect learning | Data cleaning |
# | 🎯 Irrelevant Features | Noise and complexity | Feature selection |
# | 📚 Overfitting | Memorizes training data | Regularization, more data |
# | 📉 Underfitting | Doesn't learn patterns | Better model and features |
# | 🔗 Software Integration | Difficult deployment | APIs, Docker, cloud deployment |
# | 🚀 Offline Learning & Deployment | Model becomes outdated | Retraining and monitoring |
# | 💰 Cost Involved | Expensive infrastructure | Efficient resource usage |

# %% [markdown]
# ---
#
# # 🧠 Key Takeaways
#
# ✅ Good data is more valuable than a complex algorithm.
#
# ✅ Data quality directly affects model performance.
#
# ✅ Overfitting and underfitting are among the most common modeling problems.
#
# ✅ Feature selection is essential for efficient learning.
#
# ✅ Deploying an ML model is often more challenging than training it.
#
# ✅ Successful Machine Learning systems require continuous monitoring and maintenance.
#
# ---
#
# # 📚 Conclusion
#
# Machine Learning is not just about selecting algorithms—it's about solving real-world problems with reliable data, robust models, and effective deployment strategies.
#
# By understanding these common challenges, you'll be better prepared to build models that are accurate, scalable, and practical for production environments.

# %% [markdown]
# ---
#
# # 🚀 What's Next?
#
# [**🤖 ML 07 — Applications of Machine Learning**](http://https://www.kaggle.com/code/ahmedfakhar123/ml-07-applications-of-machine-learning)
#
# You'll learn:
#
# - 🌍 What Machine Learning applications are
# - 🏥 Machine Learning in Healthcare
# - 💰 Machine Learning in Finance
# - 🛒 Machine Learning in E-commerce
# - 🚗 Machine Learning in Transportation
# - 🎬 Machine Learning in Entertainment
# - 🤖 Machine Learning in Generative AI and Robotics
# - 📱 Everyday examples of Machine Learning around us
#
# By the end, you'll understand **how Machine Learning is transforming industries and powering the intelligent systems we use every day.**
#
# ---
#
# # ❤️ Support
#
# If you found this notebook helpful:
#
# - ⭐ Upvote this notebook
# - 💬 Share your feedback in the comments
# - 🔄 Follow me for more beginner-friendly Machine Learning notebooks
#
# Happy Learning! 🚀
