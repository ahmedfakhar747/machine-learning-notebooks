# %% [markdown]
# <a href="https://www.kaggle.com/code/ahmedfakhar123/ml-51-gradient-boosting-intuition-code?scriptVersionId=351632532" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ---
#
# # 📈 ML 51 — Gradient Boosting | Intuition & Code
#
# ---

# %%
import numpy as np
import pandas as pd
