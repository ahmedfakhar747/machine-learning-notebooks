# %% [markdown]
# <a href="https://www.kaggle.com/code/ahmedfakhar123/ml-02-ai-vs-machine-learning-vs-deep-learning?scriptVersionId=337405686" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ---
# # 🤖 AI vs ML vs DL
#
# ### *Understanding the Relationship Between Artificial Intelligence, Machine Learning & Deep Learning*
#
# ---

# %% [markdown]
# > **A beginner-friendly guide to understand the relationship and differences between Artificial Intelligence (AI), Machine Learning (ML), and Deep Learning (DL).**
#
# <div align="center">
#     <img src="https://atalnetworks.com/wp-content/uploads/2025/04/AI-vs.-Machine-Learning-vs.-Deep-Learning-Whats-the-Difference-2-1024x572.webp" width=550>
#     <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRk-D3NqR4sSnEHkiKlp5_aJ2-R4EeeSMGnCaZ5xnVo_jMKe8tX5Ik70Dw&s=10" width=550>
# </div>

# %% [markdown]
# ## 📌 Introduction
#
# Artificial Intelligence (**AI**), Machine Learning (**ML**), and Deep Learning (**DL**) are among the most commonly used terms in modern technology. Although they are closely related, they are **not the same thing**.
#
# This notebook explains:
#
# * What AI, ML, and DL are
# * How they relate to each other
# * Their differences
# * Real-world examples
# * Applications
# * Which one to learn first
#
# By the end of this notebook, you'll have a crystal-clear understanding of these concepts.
#
#
# ## 📚 Learning Objectives
#
# After completing this notebook, you will be able to:
#
# * ✅ Understand Artificial Intelligence
# * ✅ Understand Machine Learning
# * ✅ Understand Deep Learning
# * ✅ Explain their relationship
# * ✅ Compare them using practical examples
# * ✅ Identify real-world applications

# %% [markdown]
# ---
#
# # 🧠 What is Artificial Intelligence (AI)?
#
# Artificial Intelligence is the broad field of computer science focused on creating machines that can perform tasks requiring human intelligence.
#
# <div align="center">
#     <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSjjJf73m9l9iHu0uAwPVFFzdGIViEz8xe9J2-KDhycsH90D2p_c0ev-iwb&s=10" width=500>
# </div>
#
# These tasks include:
#
# * Learning
# * Reasoning
# * Decision making
# * Planning
# * Problem solving
# * Language understanding
# * Vision
#
# ### Examples
#
# * ChatGPT
# * Siri
# * Self-driving cars
# * Google Translate
# * Chess-playing computers

# %% [markdown]
# ---
#
# # 🤖 What is Machine Learning (ML)?
#
# Machine Learning is a subset of AI.
#
# Instead of writing explicit rules, we provide data and allow the machine to **learn patterns automatically**.
#
# <div align="center">
#     <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS0LOGAbfI0_PTT3664yGq9-TmmC61mDcl6tpjYzJlWpLTmt_Cp6xA7VCxQ&s=10" width=500>
# </div>
#
# ### Workflow
#
# Data → Learning Algorithm → Trained Model → Prediction
#
# ### Examples
#
# * Spam detection
# * House price prediction
# * Recommendation systems
# * Credit card fraud detection

# %% [markdown]
# ---
#
# # 🧠 What is Deep Learning (DL)?
#
# Deep Learning is a subset of Machine Learning.
#
# It uses **Artificial Neural Networks** with many layers to automatically learn complex patterns from huge amounts of data.
#
# Deep Learning powers many of today's AI breakthroughs.
#
# <div align="center">
#     <img src="https://d3lkc3n5th01x7.cloudfront.net/wp-content/uploads/2023/06/16031110/Deep-learning.png" width=500>
# </div>
#
# ### Examples
#
# * Image recognition
# * Face detection
# * Speech recognition
# * ChatGPT
# * Autonomous vehicles
#
# ---
#
# # 🎯 Relationship Between AI, ML & DL
#
#
# ```text
# AI
# └── ML
#       └── DL
# ```
#
# Think of them like circles:
#
# * AI is the biggest circle.
# * ML is inside AI.
# * DL is inside ML.
#
# <div align="center">
#     <img src="https://media.licdn.com/dms/image/v2/D5622AQGUH-uOSANuJg/feedshare-shrink_800/B56Zvp5JwDI4Ak-/0/1769155632421?e=2147483647&v=beta&t=kG_HWTfp0zJ-qsGXjntdaQhSmEP2TKojUQgEqe9rZ_M" width=500>
# </div>

# %% [markdown]
# ---
#
# # ⚖️ AI vs ML vs DL
#
# | Feature              | AI                      | ML                 | DL                   |
# | -------------------- | ----------------------- | ------------------ | -------------------- |
# | Full Form            | Artificial Intelligence | Machine Learning   | Deep Learning        |
# | Scope                | Broadest field          | Subset of AI       | Subset of ML         |
# | Uses Data            | Sometimes               | Yes                | Yes (Large datasets) |
# | Learns Automatically | Not always              | Yes                | Yes                  |
# | Feature Engineering  | Mostly manual           | Manual + automatic | Automatic            |
# | Training Time        | Low                     | Medium             | High                 |
# | Computing Power      | Low                     | Medium             | Very High            |
# | Accuracy             | Moderate                | High               | Very High            |
# | Human Intervention   | High                    | Medium             | Low                  |

# %% [markdown]
# ---
#
# # 🌍 Real-World Examples
#
# ## 🤖 Artificial Intelligence
#
# * Smart assistants
# * Robotics
# * Expert systems
# * Game-playing agents
#
#
# ## 📈 Machine Learning
#
# * Netflix recommendations
# * Spam filtering
# * Stock prediction
# * Customer segmentation
#
#
# ## 🧠 Deep Learning
#
# * ChatGPT
# * Google Gemini
# * Image generation
# * Face recognition
# * Medical image diagnosis
# * Speech-to-text

# %% [markdown]
# ---
#
# # 💡 When Should You Use Each?
#
# ### Use AI
#
# When solving problems involving intelligent decision-making.
#
# Examples:
#
# * Rule-based systems
# * Robotics
# * Planning systems
#
#
# ### Use ML
#
# When you have structured data and want predictions.
#
# Examples:
#
# * Sales forecasting
# * Fraud detection
# * Customer churn prediction
#
#
# ### Use DL
#
# When dealing with massive datasets and unstructured data.
#
# Examples:
#
# * Images
# * Audio
# * Videos
# * Natural language

# %% [markdown]
# ---
#
# # 🚀 Why Deep Learning Became Popular
#
# Deep Learning became successful because of:
#
# * Faster GPUs
# * Huge datasets
# * Better neural network architectures
# * Increased computing power
#
# ---
#
# # 🛠️ Popular Libraries
#
# ## AI
#
# * Python
# * OpenCV
# * PyTorch
# * TensorFlow
#
#
#
# ## Machine Learning
#
# * Scikit-learn
# * XGBoost
# * LightGBM
# * CatBoost
#
#
#
# ## Deep Learning
#
# * TensorFlow
# * Keras
# * PyTorch

# %% [markdown]
# ---
#
# # 🎯 Key Takeaways
#
# * AI is the broad field of creating intelligent machines.
# * ML is a subset of AI that learns from data.
# * DL is a subset of ML that uses deep neural networks.
# * Every DL system is ML, and every ML system is AI—but not every AI system uses ML.
#
# ---
#
# # 📝 Summary
#
# | AI                          | ML                | DL                                |
# | --------------------------- | ----------------- | --------------------------------- |
# | Creates intelligent systems | Learns from data  | Learns using deep neural networks |
# | Broad field                 | Subset of AI      | Subset of ML                      |
# | Can be rule-based           | Data-driven       | Data + Neural Networks            |
# | Moderate complexity         | Higher complexity | Highest complexity                |

# %% [markdown]
# ---
#
# # 💬 Conclusion
#
# Artificial Intelligence is the foundation of intelligent systems, Machine Learning enables systems to learn from data, and Deep Learning takes this further by using multi-layer neural networks to solve highly complex tasks. Understanding the relationship between these three fields is the first step toward becoming an AI Engineer.

# %% [markdown]
# ---
#
# # 📚 What's Next?
#
# ➡️ [**🤖 ML 03 — Types of Machine Learning**](https://www.kaggle.com/code/ahmedfakhar123/ml-02-ai-vs-machine-learning-vs-deep-learning)
# - Supervised Learning
# - Unsupervised Learning
# - Reinforcement Learning
#
# ---
#
# # ❤️ Support
#
# If you found this notebook helpful:
#
# ⭐ Upvote the notebook
# 💬 Share your feedback in the comments
# 🔄 Follow for more beginner-friendly AI & Machine Learning notebooks
#
# **Happy Learning! 🚀**
