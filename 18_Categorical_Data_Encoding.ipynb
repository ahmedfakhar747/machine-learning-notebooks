# %% [markdown]
# ---
# # 🤖 ML 18 — Encoding Categorical Data for Machine Learning
#
# ### **Convert Text Features into Numbers with Label & Ordinal Encoding**
#
# ---

# %% [markdown]
# # 🚀 Introduction
#
# Machine Learning models can only work with **numerical data**, but many real-world datasets contain **categorical (text) features** such as gender, education level, city, or product category. Before training a model, these categorical values must be converted into numbers without losing their meaning.
#
# In this notebook, you'll learn the two most common categorical encoding techniques: **Label Encoding** and **Ordinal Encoding**. You'll understand how each method works, when to use it, and the key differences between them through practical examples. By the end, you'll be able to confidently prepare categorical features for Machine Learning models. 🚀

# %% [markdown]
# ---
# # 📦 Importing Required Libraries
#
# We'll import the libraries required for data manipulation and categorical feature encoding.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# # 📖 1. Reading the Dataset
#
# Let's load the dataset and explore the categorical features that we'll encode throughout this notebook.

# %%
df = pd.read_csv("/kaggle/input/datasets/ahmedfakhar123/customer-purchase-prediction-dataset/Customer_Encoding_Dataset.csv")
df
# Out:
#      age  gender     review    education purchased
# 0     38    Male    Average      Diploma        No
# 1     24  Female       Good     Bachelor       Yes
# 2     23  Female    Average      Diploma        No
# 3     21    Male  Excellent     Bachelor       Yes
# 4     21  Female       Poor      Diploma        No
# ..   ...     ...        ...          ...       ...
# 115   49  Female       Poor  High School        No
# 116   46  Female    Average      Diploma        No
# 117   38    Male       Good      Diploma       Yes
# 118   43    Male  Excellent      Diploma        No
# 119   36  Female    Average     Bachelor       Yes
#
# [120 rows x 5 columns]

# %% [markdown]
# ---
# # 🔍 2. Understanding the Dataset
#
# Our dataset contains both numerical and categorical features.
#
# | Feature   | Type                  |
# | --------- | --------------------- |
# | Age       | Numerical             |
# | Gender    | Categorical (Nominal) |
# | Review    | Categorical (Ordinal) |
# | Education | Categorical (Ordinal) |
# | Purchased | Target                |
